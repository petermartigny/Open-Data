# %%
import pandas as pd
pd.set_option('display.max_columns', False)
import time

# %%
start = time.time()
data = pd.read_csv('Fête de la Musique 2016 [officiel].0201.csv', sep=';')
print(time.time() - start)
# Out:
# 0.18063044548034668

# %%
data.head(3)
# Out:
#    Identifiant           ...           Accès / Itinéraire - SR
# 0     13931362           ...                               NaN
# 1     52785431           ...                               NaN
# 2      1793668           ...                               NaN
#
# [3 rows x 160 columns]

# %%
data.columns.tolist()
# Out:
# ['Identifiant',
#  'Titre - EN',
#  'Titre - FR',
#  'Titre - DE',
#  'Titre - JA',
#  'Titre - PT',
#  'Titre - ES',
#  'Titre - IT',
#  'Titre - NL',
#  'Titre - TR',
#  'Titre - UK',
#  'Titre - SL',
#  'Titre - SQ',
#  'Titre - OC',
#  'Titre - SR',
#  'Description - EN',
#  'Description - FR',
#  'Description - DE',
#  'Description - JA',
#  'Description - PT',
#  'Description - ES',
#  'Description - IT',
#  'Description - NL',
#  'Description - TR',
#  'Description - UK',
#  'Description - SL',
#  'Description - SQ',
#  'Description - OC',
#  'Description - SR',
#  'Description longue - EN',
#  'Description longue - FR',
#  'Description longue - DE',
#  'Description longue - JA',
#  'Description longue - PT',
#  'Description longue - ES',
#  'Description longue - IT',
#  'Description longue - NL',
#  'Description longue - TR',
#  'Description longue - UK',
#  'Description longue - SL',
#  'Description longue - SQ',
#  'Description longue - OC',
#  'Description longue - SR',
# ...

# %%
data['Ville'].value_counts()
# Out:
# Paris                         330
# Tarbes                         68
# Perpignan                      33
# Lyon                           29
# Toulon                         28
# Rennes                         27
# Nantes                         26
# Auxerre                        25
# Guebwiller                     25
# Épernay                        24
# Saint-Jean-de-Maurienne        23
# La Rochelle                    22
# Orléans                        22
# Lorient                        20
# Bordeaux                       20
# Senlis                         18
# Beijing                        18
# Agen                           17
# Bressuire                      17
# Vesoul                         16
# Arbois                         16
# Bourgoin-Jallieu               14
# Orange                         13
# Le Mans                        13
# Nice                           12
# Bagnols-sur-Cèze               12
# Obernai                        12
# ...
